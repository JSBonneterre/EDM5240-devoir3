# %%
import pandas as pan

# %%
demande = pan.read_csv("ati.csv", low_memory=False)

# %%
demande
# Out:
#        year  month request_number  \
# 0      2016      3   A-2015-00070
# 1      2017      5   A-2016-00059
# 2      2016      3   A-2015-00059
# 3      2016      7   A-2016-00076
# 4      2016      3   A-2015-00113
# 5      2016      3   A-2015-00109
# 6      2016      3   A-2015-00108
# 7      2016      3   A-2015-00107
# 8      2016      3   A-2015-00082
# 9      2016      3   A-2015-00106
# 10     2016      3   A-2015-00100
# 11     2016      3   A-2015-00098
# 12     2016      3   A-2015-00085
# 13     2016      3   A-2015-00084
# 14     2016      3   A-2015-00063
# 15     2016      3   A-2015-00061
# 16     2016      3   A-2015-00058
# 17     2016      3   A-2015-00057
# 18     2016      3   A-2015-00052
# 19     2016      3   A-2014-00183
# 20     2016      3   A-2014-00182
# 21     2016      3   A-2014-00161
# 22     2016      3   A-2014-00160
# 23     2016      7   A-2016-00071
# 24     2017      7   A-2017-00063
# 25     2016     10   A-2016-00121
# ...

# %%
demande.shape
# Out:
# (28294, 9)

# %%
demande.columns
# Out:
# Index(['year', 'month', 'request_number', 'summary_en', 'summary_fr',
#        'disposition', 'pages', 'owner_org', 'owner_org_title'],
#       dtype='object')

# %%
demande.year.value_counts()
# Out:
# 2017    14284
# 2016    13275
# 2018      735
# Name: year, dtype: int64

# %%
demande.owner_org_title.value_counts()
# Out:
# Global Affairs Canada | Affaires mondiales Canada                                                                                                                1799
# National Defence | Défense nationale                                                                                                                             1703
# Employment and Social Development Canada | Emploi et Développement social Canada                                                                                 1538
# Innovation, Science and Economic Development Canada | Innovation, Sciences et Développement économique Canada                                                    1395
# Immigration, Refugees and Citizenship Canada | Immigration, Réfugiés et Citoyenneté Canada                                                                       1394
# ...

# %% [markdown]
# **On peut donc voir à qui il ya  eu le plus de demandes d'Accès à l'information**

# %%
demande.summary_fr.value_counts()
# Out:
# Une copie de documents concernant le HMS Terror                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  72
# ...

# %% [markdown]
# **ici on remarque que le navire bombarde HMS Terror a été un sujet populaire!**

# %%
demande.groupby("owner_org_title").pages.sum().sort_values(ascending=False)
# Out:
# owner_org_title
# Elections Canada | Élections Canada                                                                                                      1704954
# Employment and Social Development Canada | Emploi et Développement social Canada                                                         1061509
# Library and Archives Canada | Bibliothèque et Archives Canada                                                                             620166
# Royal Canadian Mounted Police | Gendarmerie royale du Canada                                                                              215324
# Fisheries and Oceans Canada | Pêches et Océans Canada                                                                                     213030
# Innovation, Science and Economic Development Canada | Innovation, Sciences et Développement économique Canada                             189478
# ...

# %% [markdown]
# **On remarque donc que c'est Élections Canada qui a donné le plus de pages de documentation dans ces demande d'accès**

# %%
demande.month.value_counts()
# Out:
# 3     2918
# 6     2760
# 9     2676
# 5     2538
# 10    2462
# 7     2406
# 11    2373
# 12    2354
# 8     2235
# 4     2079
# 1     2038
# 2     1424
# 0       28
# 13       1
# 55       1
# 66       1
# Name: month, dtype: int64

# %% [markdown]
# **Je voulais voir s'il y avait un moment dans l'année où il y avait plus de demandes! On remarque que pas vraiment...sauf janvier et février ou c'est vraiment tranquille. Après il y a mars en 1ere position et on retourne dans le bas de classement pour avril... Je me demande ce qui est le plus demandé en mars!**

# %%
demande.groupby("month").owner_org_title.sum().sort_values(ascending=False)
# Out:
# month
# 66              Canadian Heritage | Patrimoine canadien
# 55    Canada Border Services Agency | Agence des ser...
# 13    Business Development Bank of Canada | Banque d...
# 0     Atomic Energy of Canada Limited | Énergie atom...
# 12    Agriculture and Agri-Food Canada | Agriculture...
# 1     Agriculture and Agri-Food Canada | Agriculture...
# 9     Agriculture and Agri-Food Canada | Agriculture...
# 11    Agriculture and Agri-Food Canada | Agriculture...
# 5     Agriculture and Agri-Food Canada | Agriculture...
# 4     Agriculture and Agri-Food Canada | Agriculture...
# 8     Agriculture and Agri-Food Canada | Agriculture...
# 10    Agriculture and Agri-Food Canada | Agriculture...
# 6     Agriculture and Agri-Food Canada | Agriculture...
# 3     Agriculture and Agri-Food Canada | Agriculture...
# 2     Agriculture and Agri-Food Canada | Agriculture...
# 7     Agriculture and Agri-Food Canada | Agriculture...
# Name: owner_org_title, dtype: object

# %%
demande.groupby("owner_org_title").month.sort_values
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-74eeeb930d58> in <module>()
# ----> 1 demande.groupby("owner_org_title").month.sort_values
#
# D:\Anaconda\lib\site-packages\pandas\core\groupby.py in __getattr__(self, attr)
#     546             return self[attr]
#     547         if hasattr(self.obj, attr):
# --> 548             return self._make_wrapper(attr)
#     549
#     550         raise AttributeError("%r object has no attribute %r" %
#
# D:\Anaconda\lib\site-packages\pandas\core\groupby.py in _make_wrapper(self, name)
#     560                    "using the 'apply' method".format(kind, name,
#     561                                                      type(self).__name__))
# --> 562             raise AttributeError(msg)
#     563
#     564         # need to setup the selection
#
# ...

# %%
mars = demande.month == "3"
# Out:
# D:\Anaconda\lib\site-packages\pandas\core\ops.py:798: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = getattr(x, name)(y)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-1809827a07f8> in <module>()
# ----> 1 mars = demande.month == "3"
#
# D:\Anaconda\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#     859
#     860             with np.errstate(all='ignore'):
# --> 861                 res = na_op(values, other)
#     862             if is_scalar(res):
#     863                 raise TypeError('Could not compare %s type with Series' %
#
# D:\Anaconda\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#     798                     result = getattr(x, name)(y)
#     799                 if result is NotImplemented:
# ...

# %%
demande.month
# Out:
# 0         3
# 1         5
# 2         3
# 3         7
# 4         3
# 5         3
# 6         3
# 7         3
# 8         3
# 9         3
# 10        3
# 11        3
# 12        3
# 13        3
# 14        3
# 15        3
# 16        3
# 17        3
# 18        3
# 19        3
# 20        3
# 21        3
# 22        3
# 23        7
# 24        7
# 25       10
# 26        4
# 27        4
# 28        4
# 29        4
#          ..
# 28264     5
# 28265    10
# 28266    11
# 28267     2
# 28268     4
# 28269     5
# 28270     5
# 28271     5
# 28272    11
# 28273    11
# 28274     3
# 28275    10
# 28276    10
# 28277    10
# 28278    11
# 28279     8
# 28280     6
# 28281     2
# 28282     2
# 28283     3
# 28284     1
# 28285     4
# 28286     4
# 28287     5
# 28288     5
# 28289     7
# 28290     7
# 28291     7
# 28292    10
# 28293    12
# Name: month, Length: 28294, dtype: int64

# %%
mars = demande.month == "3"
# Out:
# D:\Anaconda\lib\site-packages\pandas\core\ops.py:798: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = getattr(x, name)(y)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-1809827a07f8> in <module>()
# ----> 1 mars = demande.month == "3"
#
# D:\Anaconda\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#     859
#     860             with np.errstate(all='ignore'):
# --> 861                 res = na_op(values, other)
#     862             if is_scalar(res):
#     863                 raise TypeError('Could not compare %s type with Series' %
#
# D:\Anaconda\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#     798                     result = getattr(x, name)(y)
#     799                 if result is NotImplemented:
# ...

# %%
mars = month(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-f8f02f01c77e> in <module>()
# ----> 1 mars = month(3)
#
# NameError: name 'month' is not defined

# %%
mars = demande.month(3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-5f9a6f62d23f> in <module>()
# ----> 1 mars = demande.month(3)
#
# TypeError: 'Series' object is not callable

# %%
demande.groupby("owner_org_title")

# %%
demande.groupby("owner_org_title").month

# %%
demande.groupby("owner_org_title").month.value_counts(ascending=False)
# Out:
# owner_org_title                                                                                             month
# Administrative Tribunals Support Service of Canada | Service canadien d'appui aux tribunaux administratifs  3         6
#                                                                                                             5         3
#                                                                                                             6         3
#                                                                                                             7         2
#                                                                                                             1         1
#                                                                                                             4         1
#                                                                                                             8         1
# ...

# %%
demande.groupby("month").owner_org_title.value_counts(ascending=False)
# Out:
# month  owner_org_title
# 0      Shared Services Canada | Services partagés Canada                                                                                                                 24
#        Atomic Energy of Canada Limited | Énergie atomique du Canada, Limitée                                                                                              1
#        Canada Economic Development for Quebec Regions | Développement économique Canada pour les régions du Québec                                                        1
#        Canadian Air Transport Security Authority | Administration canadienne de la sûreté du transport aérien                                                             1
#        Federal Economic Development Agency for Southern Ontario | Agence fédérale de développement économique pour le Sud de l'Ontario                                    1
# ...

# %% [markdown]
# **ça me permet de voir qu'elles ont été les demandes par mois! Faudrait juste que je gosse dans les paramètes pour afficher mars!**

# %%
pan.set_option("display.max_rows",999)

# %%
demande.groupby("month").owner_org_title.value_counts(ascending=False)
# Out:
# month  owner_org_title
# 0      Shared Services Canada | Services partagés Canada                                                                                                                 24
#        Atomic Energy of Canada Limited | Énergie atomique du Canada, Limitée                                                                                              1
#        Canada Economic Development for Quebec Regions | Développement économique Canada pour les régions du Québec                                                        1
#        Canadian Air Transport Security Authority | Administration canadienne de la sûreté du transport aérien                                                             1
#        Federal Economic Development Agency for Southern Ontario | Agence fédérale de développement économique pour le Sud de l'Ontario                                    1
# ...

# %% [markdown]
# **En augmentant le nombre de "max rows" je suis en mesure de regarder les demandes au 3e mois, donc mars et voir qu'Affaires mondiales Canada et Santé Canada ont été la cible de beaucoup de demandes durant les mois de mars. **
